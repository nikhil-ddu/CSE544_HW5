# %%
import numpy as np
import matplotlib.pyplot as plt
import pylab
x=np.genfromtxt('A5_q2.dat',dtype="double",delimiter=",")
xlist=[]
ylist=[]
for i in range(x.shape[0]):
    xlist.append(x[i][0])
    ylist.append(x[i][1])

# %%
sse=0
mape=0
ypred=[]

xtrain = xlist
xbar = np.mean(xtrain)
ybar = np.mean(ylist)

#print(xbar, ybar)

b1 = sum(np.multiply(np.subtract(xtrain,xbar),np.subtract(ylist,ybar)))/sum(np.multiply(np.subtract(xtrain,xbar),np.subtract(xtrain,xbar)))
b0 = ybar - b1*xbar
#print(b0)
#print(b1)

ypred = np.multiply(xtrain,b1)
ypred = [x+b0 for x in ypred]

#print(ypred)

mape=sum(np.divide(abs(np.subtract(ypred, ylist)), ylist))/len(ylist)
print("mape % -> ",mape*100 )

sse=sum(np.multiply(np.subtract(ypred,ylist),np.subtract(ypred,ylist)))
print("sse -> ",sse)

#print("mape is ",mape," %")
#print("sse is ",sse)
plt.plot(xlist,ylist,label="original")
plt.plot(xlist,ypred,label="regression( Y = X )")
plt.xlabel('server CPU usage percentage(X)')
plt.ylabel('response time(Y)')
pylab.legend(loc='upper left')   
plt.show()
#print(ypred)
# Out:
# mape % ->  167.34949087484057
# sse ->  21795.297151241608

# %%
sse=0
mape=0
ypred=[]

xtrain = np.divide(100, np.subtract(100, xlist))
xbar = np.mean(xtrain)
ybar = np.mean(ylist)

#print(xbar, ybar)

b1 = sum(np.multiply(np.subtract(xtrain,xbar),np.subtract(ylist,ybar)))/sum(np.multiply(np.subtract(xtrain,xbar),np.subtract(xtrain,xbar)))
b0 = ybar - b1*xbar
#print(b0)
#print(b1)

ypred = np.multiply(xtrain,b1)
ypred = [x+b0 for x in ypred]

#print(ypred)

mape=sum(np.divide(abs(np.subtract(ypred, ylist)), ylist))/len(ylist)
print("mape % -> ",mape*100 )

sse=sum(np.multiply(np.subtract(ypred,ylist),np.subtract(ypred,ylist)))
print("sse -> ",sse)

#print("mape is ",mape," %")
#print("sse is ",sse)
plt.plot(xtrain,ylist,label="original")
plt.plot(xtrain,ypred,label="regression( Y = X )")
plt.xlabel('server CPU usage percentage(X)')
plt.ylabel('response time(Y)')
pylab.legend(loc='upper left')   
plt.show()
#print(ypred)
# Out:
# mape % ->  2.5311139866465138
# sse ->  0.7385311633008963

# %%
sse=0
mape=0
ypred=[]

xtrain = np.divide(101**2, np.subtract(101**2, np.multiply(xlist,xlist)))
xbar = np.mean(xtrain)
ybar = np.mean(ylist)

#print(xbar, ybar)

b1 = sum(np.multiply(np.subtract(xtrain,xbar),np.subtract(ylist,ybar)))/sum(np.multiply(np.subtract(xtrain,xbar),np.subtract(xtrain,xbar)))
b0 = ybar - b1*xbar
#print(b0)
#print(b1)

ypred = np.multiply(xtrain,b1)
ypred = [x+b0 for x in ypred]

#print(ypred)

mape=sum(np.divide(abs(np.subtract(ypred, ylist)), ylist))/len(ylist)
print("mape % -> ",mape*100 )

sse=sum(np.multiply(np.subtract(ypred,ylist),np.subtract(ypred,ylist)))
print("sse -> ",sse)

#print("mape is ",mape," %")
#print("sse is ",sse)
plt.plot(xtrain,ylist,label="original")
plt.plot(xtrain,ypred,label="regression( Y = X )")
plt.xlabel('server CPU usage percentage(X)')
plt.ylabel('response time(Y)')
pylab.legend(loc='upper left')   
plt.show()
#print(ypred)
# Out:
# mape % ->  nan
# sse ->  nan
# /home/h4k3r/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   """
# /home/h4k3r/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: RuntimeWarning: invalid value encountered in subtract
#   # This is added back by InteractiveShellApp.init_path()
# /home/h4k3r/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: RuntimeWarning: invalid value encountered in double_scalars
#   # This is added back by InteractiveShellApp.init_path()

# %%
x=[1,2.3,4,5]
z=np.sum(x,10)
print(z)
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# <ipython-input-9-36db4775afec> in <module>
#       1 x=[1,2.3,4,5]
# ----> 2 z=np.sum(x,10)
#       3 print(z)
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py in sum(a, axis, dtype, out, keepdims, initial)
#    1928
#    1929     return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
# -> 1930                           initial=initial)
#    1931
#    1932
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      81                 return reduction(axis=axis, out=out, **passkwargs)
#      82
# ---> 83     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      84
#      85
#
# AxisError: axis 10 is out of bounds for array of dimension 1

# %%
np.divide(100,[1,2,3])
# Out:
# array([100.        ,  50.        ,  33.33333333])
